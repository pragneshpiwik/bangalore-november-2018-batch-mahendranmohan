# %% [markdown]
# # External Lab

# %% [markdown]
# # Part-1

# %% [markdown]
# ## About the dataset
#
# This is perhaps the best known database to be found in the pattern recognition literature. The data set contains 3 classes of 50 instances each, where each class refers to a type of iris plant.  One class is linearly separable from the other 2; the latter are NOT linearly separable from each other.
#
# Attribute Information:
#    1. sepal length in cm
#    2. sepal width in cm
#    3. petal length in cm
#    4. petal width in cm
#    5. class:
#       -- Iris Setosa
#       -- Iris Versicolour
#       -- Iris Virginica

# %% [markdown]
# ### Read the dataset and store it in the dataframe named Iris

# %%
import pandas as pd
import matplotlib.pyplot as plt
Iris = pd.read_csv("C:/DATA/Programming/AIML/TestAssignment/Lab External Residency 1/Iris.csv")

# Make the graphs a bit prettier, and bigger
#pd.set_option('display.mpl_style', 'default')

# This is necessary to show lots of columns in pandas 0.12. 
# Not necessary in pandas 0.13.
#pd.set_option('display.width', 5000) 
#pd.set_option('display.max_columns', 60)

#plt.rcParams['figure.figsize'] = (15, 5)

# %% [markdown]
# ### Find out the datatypes of each and every column

# %%
#Data types of each column
Iris.dtypes
# Out:
# Sepal Length (in cm)    float64
# Sepal Width in (cm)     float64
# Petal length (in cm)    float64
# Petal width (in cm)     float64
# Class                    object
# dtype: object

# %% [markdown]
# ### Print top 10 & bottom 10 samples from the dataframe

# %%
#Print top 10 
Iris.head(10)

#print bottom 10
Iris.tail(10)
# Out:
#      Sepal Length (in cm)  Sepal Width in (cm)  Petal length (in cm)  Petal width (in cm)           Class
# 140                   6.7                  3.1                   5.6                  2.4  Iris-virginica
# 141                   6.9                  3.1                   5.1                  2.3  Iris-virginica
# 142                   5.8                  2.7                   5.1                  1.9  Iris-virginica
# 143                   6.8                  3.2                   5.9                  2.3  Iris-virginica
# 144                   6.7                  3.3                   5.7                  2.5  Iris-virginica
# 145                   6.7                  3.0                   5.2                  2.3  Iris-virginica
# 146                   6.3                  2.5                   5.0                  1.9  Iris-virginica
# 147                   6.5                  3.0                   5.2                  2.0  Iris-virginica
# 148                   6.2                  3.4                   5.4                  2.3  Iris-virginica
# 149                   5.9                  3.0                   5.1                  1.8  Iris-virginica

# %% [markdown]
# ### Find the shape of the dataset

# %%
#Ans: Find the shape of the dataset
Iris.shape
# Out:
# (150, 5)

# %% [markdown]
# ### Set the index of the dataframe to be the first column

# %%
Iris.columns.tolist()[0]
#Ans: Set the index of the dataframe to be the first column
Iris.reset_index().set_index(Iris.columns.tolist()[0],inplace=True)
Iris.shape
# Out:
# (150, 5)

# %% [markdown]
# ### Use iloc function to print all the rows of the 3rd column

# %%
#Ans: Use iloc function to print all the rows of the 3rd column
Iris.iloc[:,2]
# Out:
# 0      1.4
# 1      1.4
# 2      1.3
# 3      1.5
# 4      1.4
# 5      1.7
# 6      1.4
# 7      1.5
# 8      1.4
# 9      1.5
# 10     1.5
# 11     1.6
# 12     1.4
# 13     1.1
# 14     1.2
# 15     1.5
# 16     1.3
# 17     1.4
# 18     1.7
# 19     1.5
# 20     1.7
# 21     1.5
# 22     1.0
# 23     1.7
# 24     1.9
# 25     1.6
# 26     1.6
# 27     1.5
# 28     1.4
# 29     1.6
#       ...
# 120    5.7
# 121    4.9
# 122    6.7
# 123    4.9
# 124    5.7
# 125    6.0
# 126    4.8
# 127    4.9
# 128    5.6
# 129    5.8
# 130    6.1
# 131    6.4
# 132    5.6
# 133    5.1
# 134    5.6
# 135    6.1
# 136    5.6
# 137    5.5
# 138    4.8
# 139    5.4
# 140    5.6
# 141    5.1
# 142    5.1
# 143    5.9
# 144    5.7
# 145    5.2
# 146    5.0
# 147    5.2
# 148    5.4
# 149    5.1
# Name: Petal length (in cm), Length: 150, dtype: float64

# %% [markdown]
# ### Slicing
# Print only the Sepal width and Sepal Length for first 10 rows

# %%
Iris.info()
#Ans: Print only the sepal width and sepal length for first 10 rows
Iris[["Sepal Width in (cm)","Sepal Length (in cm)"]].head(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
# Sepal Length (in cm)    150 non-null float64
# Sepal Width in (cm)     150 non-null float64
# Petal length (in cm)    150 non-null float64
# Petal width (in cm)     150 non-null float64
# Class                   150 non-null object
# dtypes: float64(4), object(1)
# memory usage: 5.9+ KB
#    Sepal Width in (cm)  Sepal Length (in cm)
# 0                  3.5                   5.1
# 1                  3.0                   4.9
# 2                  3.2                   4.7
# 3                  3.1                   4.6
# 4                  3.6                   5.0
# 5                  3.9                   5.4
# 6                  3.4                   4.6
# 7                  3.4                   5.0
# 8                  2.9                   4.4
# 9                  3.1                   4.9

# %% [markdown]
# ### Using Logical statements for indexing
# Print all the columns of row which has class name "Iris-setosa"

# %%
Iris['Class'].value_counts()
Iris[Iris['Class'] == "Iris-setosa"]['Class'].value_counts()
#Ans Print all columns of row which has class name "Iris-setosa"
Iris[Iris['Class'] == "Iris-setosa"]
# Out:
#     Sepal Length (in cm)  Sepal Width in (cm)  Petal length (in cm)  Petal width (in cm)        Class
# 0                    5.1                  3.5                   1.4                  0.2  Iris-setosa
# 1                    4.9                  3.0                   1.4                  0.2  Iris-setosa
# 2                    4.7                  3.2                   1.3                  0.2  Iris-setosa
# 3                    4.6                  3.1                   1.5                  0.2  Iris-setosa
# 4                    5.0                  3.6                   1.4                  0.2  Iris-setosa
# 5                    5.4                  3.9                   1.7                  0.4  Iris-setosa
# 6                    4.6                  3.4                   1.4                  0.3  Iris-setosa
# 7                    5.0                  3.4                   1.5                  0.2  Iris-setosa
# 8                    4.4                  2.9                   1.4                  0.2  Iris-setosa
# 9                    4.9                  3.1                   1.5                  0.1  Iris-setosa
# 10                   5.4                  3.7                   1.5                  0.2  Iris-setosa
# 11                   4.8                  3.4                   1.6                  0.2  Iris-setosa
# 12                   4.8                  3.0                   1.4                  0.1  Iris-setosa
# 13                   4.3                  3.0                   1.1                  0.1  Iris-setosa
# 14                   5.8                  4.0                   1.2                  0.2  Iris-setosa
# 15                   5.7                  4.4                   1.5                  0.4  Iris-setosa
# 16                   5.4                  3.9                   1.3                  0.4  Iris-setosa
# 17                   5.1                  3.5                   1.4                  0.3  Iris-setosa
# 18                   5.7                  3.8                   1.7                  0.3  Iris-setosa
# 19                   5.1                  3.8                   1.5                  0.3  Iris-setosa
# 20                   5.4                  3.4                   1.7                  0.2  Iris-setosa
# 21                   5.1                  3.7                   1.5                  0.4  Iris-setosa
# 22                   4.6                  3.6                   1.0                  0.2  Iris-setosa
# 23                   5.1                  3.3                   1.7                  0.5  Iris-setosa
# 24                   4.8                  3.4                   1.9                  0.2  Iris-setosa
# 25                   5.0                  3.0                   1.6                  0.2  Iris-setosa
# 26                   5.0                  3.4                   1.6                  0.4  Iris-setosa
# 27                   5.2                  3.5                   1.5                  0.2  Iris-setosa
# 28                   5.2                  3.4                   1.4                  0.2  Iris-setosa
# 29                   4.7                  3.2                   1.6                  0.2  Iris-setosa
# 30                   4.8                  3.1                   1.6                  0.2  Iris-setosa
# 31                   5.4                  3.4                   1.5                  0.4  Iris-setosa
# 32                   5.2                  4.1                   1.5                  0.1  Iris-setosa
# 33                   5.5                  4.2                   1.4                  0.2  Iris-setosa
# 34                   4.9                  3.1                   1.5                  0.1  Iris-setosa
# 35                   5.0                  3.2                   1.2                  0.2  Iris-setosa
# 36                   5.5                  3.5                   1.3                  0.2  Iris-setosa
# 37                   4.9                  3.1                   1.5                  0.1  Iris-setosa
# 38                   4.4                  3.0                   1.3                  0.2  Iris-setosa
# 39                   5.1                  3.4                   1.5                  0.2  Iris-setosa
# 40                   5.0                  3.5                   1.3                  0.3  Iris-setosa
# 41                   4.5                  2.3                   1.3                  0.3  Iris-setosa
# 42                   4.4                  3.2                   1.3                  0.2  Iris-setosa
# 43                   5.0                  3.5                   1.6                  0.6  Iris-setosa
# 44                   5.1                  3.8                   1.9                  0.4  Iris-setosa
# 45                   4.8                  3.0                   1.4                  0.3  Iris-setosa
# 46                   5.1                  3.8                   1.6                  0.2  Iris-setosa
# 47                   4.6                  3.2                   1.4                  0.2  Iris-setosa
# 48                   5.3                  3.7                   1.5                  0.2  Iris-setosa
# 49                   5.0                  3.3                   1.4                  0.2  Iris-setosa

# %% [markdown]
# ### Multiply Sepal Length and width and store it under the column name "SepalExtra" in the same Iris dataframe

# %%
Iris.index
Iris.describe(include="all")
#Ans: Multiply Sepal Length and width and store in "SepalExtra"
Iris["SepalExtra"]=Iris["Sepal Length (in cm)"]*Iris["Sepal Width in (cm)"]
Iris
# Out:
#      Sepal Length (in cm)  Sepal Width in (cm)  Petal length (in cm)  Petal width (in cm)           Class  SepalExtra
# 0                     5.1                  3.5                   1.4                  0.2     Iris-setosa       17.85
# 1                     4.9                  3.0                   1.4                  0.2     Iris-setosa       14.70
# 2                     4.7                  3.2                   1.3                  0.2     Iris-setosa       15.04
# 3                     4.6                  3.1                   1.5                  0.2     Iris-setosa       14.26
# 4                     5.0                  3.6                   1.4                  0.2     Iris-setosa       18.00
# 5                     5.4                  3.9                   1.7                  0.4     Iris-setosa       21.06
# 6                     4.6                  3.4                   1.4                  0.3     Iris-setosa       15.64
# 7                     5.0                  3.4                   1.5                  0.2     Iris-setosa       17.00
# 8                     4.4                  2.9                   1.4                  0.2     Iris-setosa       12.76
# 9                     4.9                  3.1                   1.5                  0.1     Iris-setosa       15.19
# 10                    5.4                  3.7                   1.5                  0.2     Iris-setosa       19.98
# 11                    4.8                  3.4                   1.6                  0.2     Iris-setosa       16.32
# 12                    4.8                  3.0                   1.4                  0.1     Iris-setosa       14.40
# 13                    4.3                  3.0                   1.1                  0.1     Iris-setosa       12.90
# 14                    5.8                  4.0                   1.2                  0.2     Iris-setosa       23.20
# 15                    5.7                  4.4                   1.5                  0.4     Iris-setosa       25.08
# 16                    5.4                  3.9                   1.3                  0.4     Iris-setosa       21.06
# 17                    5.1                  3.5                   1.4                  0.3     Iris-setosa       17.85
# 18                    5.7                  3.8                   1.7                  0.3     Iris-setosa       21.66
# 19                    5.1                  3.8                   1.5                  0.3     Iris-setosa       19.38
# 20                    5.4                  3.4                   1.7                  0.2     Iris-setosa       18.36
# 21                    5.1                  3.7                   1.5                  0.4     Iris-setosa       18.87
# 22                    4.6                  3.6                   1.0                  0.2     Iris-setosa       16.56
# 23                    5.1                  3.3                   1.7                  0.5     Iris-setosa       16.83
# 24                    4.8                  3.4                   1.9                  0.2     Iris-setosa       16.32
# 25                    5.0                  3.0                   1.6                  0.2     Iris-setosa       15.00
# 26                    5.0                  3.4                   1.6                  0.4     Iris-setosa       17.00
# 27                    5.2                  3.5                   1.5                  0.2     Iris-setosa       18.20
# 28                    5.2                  3.4                   1.4                  0.2     Iris-setosa       17.68
# 29                    4.7                  3.2                   1.6                  0.2     Iris-setosa       15.04
# ..                    ...                  ...                   ...                  ...             ...         ...
# 120                   6.9                  3.2                   5.7                  2.3  Iris-virginica       22.08
# 121                   5.6                  2.8                   4.9                  2.0  Iris-virginica       15.68
# 122                   7.7                  2.8                   6.7                  2.0  Iris-virginica       21.56
# 123                   6.3                  2.7                   4.9                  1.8  Iris-virginica       17.01
# 124                   6.7                  3.3                   5.7                  2.1  Iris-virginica       22.11
# 125                   7.2                  3.2                   6.0                  1.8  Iris-virginica       23.04
# 126                   6.2                  2.8                   4.8                  1.8  Iris-virginica       17.36
# 127                   6.1                  3.0                   4.9                  1.8  Iris-virginica       18.30
# 128                   6.4                  2.8                   5.6                  2.1  Iris-virginica       17.92
# 129                   7.2                  3.0                   5.8                  1.6  Iris-virginica       21.60
# 130                   7.4                  2.8                   6.1                  1.9  Iris-virginica       20.72
# 131                   7.9                  3.8                   6.4                  2.0  Iris-virginica       30.02
# 132                   6.4                  2.8                   5.6                  2.2  Iris-virginica       17.92
# 133                   6.3                  2.8                   5.1                  1.5  Iris-virginica       17.64
# 134                   6.1                  2.6                   5.6                  1.4  Iris-virginica       15.86
# 135                   7.7                  3.0                   6.1                  2.3  Iris-virginica       23.10
# 136                   6.3                  3.4                   5.6                  2.4  Iris-virginica       21.42
# 137                   6.4                  3.1                   5.5                  1.8  Iris-virginica       19.84
# 138                   6.0                  3.0                   4.8                  1.8  Iris-virginica       18.00
# 139                   6.9                  3.1                   5.4                  2.1  Iris-virginica       21.39
# 140                   6.7                  3.1                   5.6                  2.4  Iris-virginica       20.77
# 141                   6.9                  3.1                   5.1                  2.3  Iris-virginica       21.39
# 142                   5.8                  2.7                   5.1                  1.9  Iris-virginica       15.66
# 143                   6.8                  3.2                   5.9                  2.3  Iris-virginica       21.76
# 144                   6.7                  3.3                   5.7                  2.5  Iris-virginica       22.11
# 145                   6.7                  3.0                   5.2                  2.3  Iris-virginica       20.10
# 146                   6.3                  2.5                   5.0                  1.9  Iris-virginica       15.75
# 147                   6.5                  3.0                   5.2                  2.0  Iris-virginica       19.50
# 148                   6.2                  3.4                   5.4                  2.3  Iris-virginica       21.08
# 149                   5.9                  3.0                   5.1                  1.8  Iris-virginica       17.70
#
# [150 rows x 6 columns]

# %% [markdown]
# ### Find out the mean and variance for each column but for class column

# %%
Iris[Iris.columns[0]].mean()
print("Mean of columns:")
#Ans: Mean of columns
print(Iris.mean(axis=0))

print("\nVariance of columns:")
#Ans: Variance of columns
print(Iris.var(axis=0))
# Out:
# Mean of columns:
# Sepal Length (in cm)     5.843333
# Sepal Width in (cm)      3.054000
# Petal length (in cm)     3.758667
# Petal width (in cm)      1.198667
# SepalExtra              17.806533
# dtype: float64
#
# Variance of columns:
# Sepal Length (in cm)     0.685694
# Sepal Width in (cm)      0.188004
# Petal length (in cm)     3.113179
# Petal width (in cm)      0.582414
# SepalExtra              11.348090
# dtype: float64

# %% [markdown]
# ### Write a function that accepts two numbers as input and prints them - Pass the Sepal length and sepal width of 5th row and print the output

# %%
def func_two_inputs(x,y):
    print(x,y)

#Write a function that accepts two numbers as input and prints them - Pass the Sepal length and sepal width of 5th row and print the output
func_two_inputs(Iris.iloc[4,0],Iris.iloc[4,1])
# Out:
# 5.0 3.6

# %% [markdown]
# ### Find the range of all the columns in the dataset
#
# *Range = Max value - Min value (in the column)*

# %%
#Iris.describe(include="all")
#print(Iris.iloc[:,[0]].min())
#print(Iris.iloc[:,[0]].max())
#print(Iris.iloc[:,[0]].max() - Iris.iloc[:,[0]].min())
#print(Iris._get_numeric_data())
#print(Iris.select_dtypes(include=numerics))
#print(column, Iris[column].max(), Iris[column].min(), Iris[column].max() - Iris[column].min())

#Ans: Find the range of all columns
for column in Iris._get_numeric_data():
    print(column, round(Iris[column].max() - Iris[column].min(), 2))
# Out:
# Sepal Length (in cm) 3.6
# Sepal Width in (cm) 2.4
# Petal length (in cm) 5.9
# Petal width (in cm) 2.4
# SepalExtra 20.02

# %% [markdown]
# ### Sort the entire dataset according to the column Petal width

# %%
#Ans: Sort the entire dataset by column petal width
Iris.sort_values(by="Petal width (in cm)")
# Out:
#      Sepal Length (in cm)  Sepal Width in (cm)  Petal length (in cm)  Petal width (in cm)           Class  SepalExtra
# 32                    5.2                  4.1                   1.5                  0.1     Iris-setosa       21.32
# 13                    4.3                  3.0                   1.1                  0.1     Iris-setosa       12.90
# 37                    4.9                  3.1                   1.5                  0.1     Iris-setosa       15.19
# 9                     4.9                  3.1                   1.5                  0.1     Iris-setosa       15.19
# 12                    4.8                  3.0                   1.4                  0.1     Iris-setosa       14.40
# 34                    4.9                  3.1                   1.5                  0.1     Iris-setosa       15.19
# 0                     5.1                  3.5                   1.4                  0.2     Iris-setosa       17.85
# 27                    5.2                  3.5                   1.5                  0.2     Iris-setosa       18.20
# 28                    5.2                  3.4                   1.4                  0.2     Iris-setosa       17.68
# 29                    4.7                  3.2                   1.6                  0.2     Iris-setosa       15.04
# 30                    4.8                  3.1                   1.6                  0.2     Iris-setosa       14.88
# 33                    5.5                  4.2                   1.4                  0.2     Iris-setosa       23.10
# 36                    5.5                  3.5                   1.3                  0.2     Iris-setosa       19.25
# 38                    4.4                  3.0                   1.3                  0.2     Iris-setosa       13.20
# 39                    5.1                  3.4                   1.5                  0.2     Iris-setosa       17.34
# 42                    4.4                  3.2                   1.3                  0.2     Iris-setosa       14.08
# 46                    5.1                  3.8                   1.6                  0.2     Iris-setosa       19.38
# 47                    4.6                  3.2                   1.4                  0.2     Iris-setosa       14.72
# 48                    5.3                  3.7                   1.5                  0.2     Iris-setosa       19.61
# 49                    5.0                  3.3                   1.4                  0.2     Iris-setosa       16.50
# 25                    5.0                  3.0                   1.6                  0.2     Iris-setosa       15.00
# 24                    4.8                  3.4                   1.9                  0.2     Iris-setosa       16.32
# 35                    5.0                  3.2                   1.2                  0.2     Iris-setosa       16.00
# 3                     4.6                  3.1                   1.5                  0.2     Iris-setosa       14.26
# 2                     4.7                  3.2                   1.3                  0.2     Iris-setosa       15.04
# 7                     5.0                  3.4                   1.5                  0.2     Iris-setosa       17.00
# 8                     4.4                  2.9                   1.4                  0.2     Iris-setosa       12.76
# 10                    5.4                  3.7                   1.5                  0.2     Iris-setosa       19.98
# 4                     5.0                  3.6                   1.4                  0.2     Iris-setosa       18.00
# 11                    4.8                  3.4                   1.6                  0.2     Iris-setosa       16.32
# ..                    ...                  ...                   ...                  ...             ...         ...
# 111                   6.4                  2.7                   5.3                  1.9  Iris-virginica       17.28
# 121                   5.6                  2.8                   4.9                  2.0  Iris-virginica       15.68
# 122                   7.7                  2.8                   6.7                  2.0  Iris-virginica       21.56
# 147                   6.5                  3.0                   5.2                  2.0  Iris-virginica       19.50
# 113                   5.7                  2.5                   5.0                  2.0  Iris-virginica       14.25
# 131                   7.9                  3.8                   6.4                  2.0  Iris-virginica       30.02
# 110                   6.5                  3.2                   5.1                  2.0  Iris-virginica       20.80
# 139                   6.9                  3.1                   5.4                  2.1  Iris-virginica       21.39
# 102                   7.1                  3.0                   5.9                  2.1  Iris-virginica       21.30
# 112                   6.8                  3.0                   5.5                  2.1  Iris-virginica       20.40
# 105                   7.6                  3.0                   6.6                  2.1  Iris-virginica       22.80
# 124                   6.7                  3.3                   5.7                  2.1  Iris-virginica       22.11
# 128                   6.4                  2.8                   5.6                  2.1  Iris-virginica       17.92
# 117                   7.7                  3.8                   6.7                  2.2  Iris-virginica       29.26
# 132                   6.4                  2.8                   5.6                  2.2  Iris-virginica       17.92
# 104                   6.5                  3.0                   5.8                  2.2  Iris-virginica       19.50
# 120                   6.9                  3.2                   5.7                  2.3  Iris-virginica       22.08
# 115                   6.4                  3.2                   5.3                  2.3  Iris-virginica       20.48
# 148                   6.2                  3.4                   5.4                  2.3  Iris-virginica       21.08
# 141                   6.9                  3.1                   5.1                  2.3  Iris-virginica       21.39
# 143                   6.8                  3.2                   5.9                  2.3  Iris-virginica       21.76
# 145                   6.7                  3.0                   5.2                  2.3  Iris-virginica       20.10
# 118                   7.7                  2.6                   6.9                  2.3  Iris-virginica       20.02
# 135                   7.7                  3.0                   6.1                  2.3  Iris-virginica       23.10
# 136                   6.3                  3.4                   5.6                  2.4  Iris-virginica       21.42
# 140                   6.7                  3.1                   5.6                  2.4  Iris-virginica       20.77
# 114                   5.8                  2.8                   5.1                  2.4  Iris-virginica       16.24
# 100                   6.3                  3.3                   6.0                  2.5  Iris-virginica       20.79
# 144                   6.7                  3.3                   5.7                  2.5  Iris-virginica       22.11
# 109                   7.2                  3.6                   6.1                  2.5  Iris-virginica       25.92
#
# [150 rows x 6 columns]

# %% [markdown]
# ### Remove the new column "SepalExtra" from the dataframe

# %%
#Ans: Rmove the column "SepalExtra"
Iris.drop(columns=['SepalExtra'],inplace=True)
Iris.head()
# Out:
#    Sepal Length (in cm)  Sepal Width in (cm)  Petal length (in cm)  Petal width (in cm)        Class
# 0                   5.1                  3.5                   1.4                  0.2  Iris-setosa
# 1                   4.9                  3.0                   1.4                  0.2  Iris-setosa
# 2                   4.7                  3.2                   1.3                  0.2  Iris-setosa
# 3                   4.6                  3.1                   1.5                  0.2  Iris-setosa
# 4                   5.0                  3.6                   1.4                  0.2  Iris-setosa

# %% [markdown]
# ### Take only the top 10 rows of the dataset with only first 3 columns and store it in a dataframe named "IrisSubset"

# %%
#Ans: Top10 rows with first3 columns
IrisSubset=Iris.iloc[:10,:3]
IrisSubset
# Out:
#    Sepal Length (in cm)  Sepal Width in (cm)  Petal length (in cm)
# 0                   5.1                  3.5                   1.4
# 1                   4.9                  3.0                   1.4
# 2                   4.7                  3.2                   1.3
# 3                   4.6                  3.1                   1.5
# 4                   5.0                  3.6                   1.4
# 5                   5.4                  3.9                   1.7
# 6                   4.6                  3.4                   1.4
# 7                   5.0                  3.4                   1.5
# 8                   4.4                  2.9                   1.4
# 9                   4.9                  3.1                   1.5

# %% [markdown]
# # Part-2

# %% [markdown]
# ## The dataset HR contains information collected from the survey floated by a HR within the company.
#
#
# As a part of this lab, you are expected to answer the below questions

# %% [markdown]
# ### Import numpy and Pandas

# %%
import numpy as np
import pandas as pd
#import matplotlib.pyplot as plt

# %% [markdown]
# ### Import the dataset (Note: The dataset is in .txt format) - Make sure to use delimiters

# %%
hr = pd.read_csv("C:/DATA/Programming/AIML/TestAssignment/Lab External Residency 1/HR.txt",sep="\t")
# Out:
#      Individual  Attrition  Age  BusinessTravel  DailyRate  Department  DistanceFromHome  Education  EducationField  EmployeeCount  EmployeeNumber  EnvironmentSatisfaction  Gender  HourlyRate  JobInvolvement  JobLevel  JobRole  JobSatisfaction  MaritalStatus  MonthlyIncome  MonthlyRate  NumCompaniesWorked  OverTime  PercentSalaryHike  PerformanceRating  RelationshipSatisfaction  StandardHours  StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  WorkLifeBalance  YearsAtCompany  YearsInCurrentRole  YearsSinceLastPromotion  YearsWithCurrManager
# 1465     Ind1466        No   36               2        884           2                23          2               2              1            2061                        3       1          41               4         2        3                4              2           2571        12290                   4         2                 17                  3                         3             80                 1                 17                      3                3               5                   2                        0                     3
# 1466     Ind1467        No   39               1        613           2                 6          1               2              1            2062                        4       1          42               2         3        5                1              2           9991        21457                   4         2                 15                  3                         1             80                 1                  9                      5                3               7                   7                        1                     7
# 1467     Ind1468        No   27               1        155           2                 4          3               1              1            2064                        2       1          87               4         2        4                2              2           6142         5174                   1         1                 20                  4                         2             80                 1                  6                      0                3               6                   2                        0                     3
# 1468     Ind1469        No   49               2       1023           1                 2          3               2              1            2065                        4       1          63               2         2        1                2              2           5390        13243                   2         2                 14                  3                         4             80                 0                 17                      3                2               9                   6                        0                     8
# 1469     Ind1470        No   34               1        628           2                 8          3               2              1            2068                        2       1          82               4         2        3                3              2           4404        10228                   2         2                 12                  3                         1             80                 0                  6                      3                4               4                   3                        1                     2

# %% [markdown]
# ### Print the no of rows and columns in the dataset

# %%
hr.shape
# Out:
# (1470, 35)

# %% [markdown]
# ### Find out the type of each and every column in the dataset

# %%
hr.dtypes
# Out:
# Individual                  object
# Attrition                   object
# Age                          int64
# BusinessTravel               int64
# DailyRate                    int64
# Department                   int64
# DistanceFromHome             int64
# Education                    int64
# EducationField               int64
# EmployeeCount                int64
# EmployeeNumber               int64
# EnvironmentSatisfaction      int64
# Gender                       int64
# HourlyRate                   int64
# JobInvolvement               int64
# JobLevel                     int64
# JobRole                      int64
# JobSatisfaction              int64
# MaritalStatus                int64
# MonthlyIncome                int64
# MonthlyRate                  int64
# NumCompaniesWorked           int64
# OverTime                     int64
# PercentSalaryHike            int64
# PerformanceRating            int64
# RelationshipSatisfaction     int64
# StandardHours                int64
# StockOptionLevel             int64
# TotalWorkingYears            int64
# TrainingTimesLastYear        int64
# WorkLifeBalance              int64
# YearsAtCompany               int64
# YearsInCurrentRole           int64
# YearsSinceLastPromotion      int64
# YearsWithCurrManager         int64
# dtype: object

# %% [markdown]
# ### Print out all the rows from 3rd column to 10th columns

# %%
hr.iloc[:,2:10]
# Out:
#       Age  BusinessTravel  DailyRate  Department  DistanceFromHome  Education  EducationField  EmployeeCount
# 0      41               1       1102           1                 1          2               1              1
# 1      49               2        279           2                 8          1               1              1
# 2      37               1       1373           2                 2          2               6              1
# 3      33               2       1392           2                 3          4               1              1
# 4      27               1        591           2                 2          1               2              1
# 5      32               2       1005           2                 2          2               1              1
# 6      59               1       1324           2                 3          3               2              1
# 7      30               1       1358           2                24          1               1              1
# 8      38               2        216           2                23          3               1              1
# 9      36               1       1299           2                27          3               2              1
# 10     35               1        809           2                16          3               2              1
# 11     29               1        153           2                15          2               1              1
# 12     31               1        670           2                26          1               1              1
# 13     34               1       1346           2                19          2               2              1
# 14     28               1        103           2                24          3               1              1
# 15     29               1       1389           2                21          4               1              1
# 16     32               1        334           2                 5          2               1              1
# 17     22               3       1123           2                16          2               2              1
# 18     53               1       1219           1                 2          4               1              1
# 19     38               1        371           2                 2          3               1              1
# 20     24               3        673           2                11          2               6              1
# 21     36               1       1218           1                 9          4               1              1
# 22     34               1        419           2                 7          4               1              1
# 23     21               1        391           2                15          2               1              1
# 24     34               1        699           2                 6          1               2              1
# 25     53               1       1282           2                 5          3               6              1
# 26     32               2       1125           2                16          1               1              1
# 27     42               1        691           1                 8          4               3              1
# 28     44               1        477           2                 7          4               2              1
# 29     46               1        705           1                 2          4               3              1
# ...   ...             ...        ...         ...               ...        ...             ...            ...
# 1440   36               2        688           2                 4          2               1              1
# 1441   56               3        667           2                 1          4               1              1
# 1442   29               1       1092           2                 1          4               2              1
# 1443   42               1        300           2                 2          3               1              1
# 1444   56               1        310           2                 7          2               4              1
# 1445   41               1        582           2                28          4               1              1
# 1446   34               1        704           1                28          3               3              1
# 1447   36               3        301           1                15          4               3              1
# 1448   41               1        930           1                 3          3               1              1
# 1449   32               1        529           2                 2          3               4              1
# 1450   35               1       1146           3                26          4               1              1
# 1451   38               1        345           1                10          2               1              1
# 1452   50               2        878           1                 1          4               1              1
# 1453   36               1       1120           1                11          4               3              1
# 1454   45               1        374           1                20          3               1              1
# 1455   40               1       1322           2                 2          4               1              1
# 1456   35               2       1199           2                18          4               1              1
# 1457   40               1       1194           2                 2          4               2              1
# 1458   35               1        287           2                 1          4               1              1
# 1459   29               1       1378           2                13          2               6              1
# 1460   29               1        468           2                28          4               2              1
# 1461   50               1        410           1                28          3               3              1
# 1462   39               1        722           1                24          1               3              1
# 1463   31               3        325           2                 5          3               2              1
# 1464   26               1       1167           1                 5          3               6              1
# 1465   36               2        884           2                23          2               2              1
# 1466   39               1        613           2                 6          1               2              1
# 1467   27               1        155           2                 4          3               1              1
# 1468   49               2       1023           1                 2          3               2              1
# 1469   34               1        628           2                 8          3               2              1
#
# [1470 rows x 8 columns]

# %% [markdown]
# ### Find out the no of male & female employees in the company
#
# *Hint: Use can use a condition to find out the no of 1s and 0s in gender and sum it*

# %%
hr["Gender"].value_counts()
#hr.groupby('Gender').count()
hr.groupby('Gender').size()
# Out:
# Gender
# 1    882
# 2    588
# dtype: int64

# %% [markdown]
# ### Find out the IQR for the column - Age
#
# *Hint: IQR - Interquartile range = 75th percentile - 25th percentile*

# %%
#hr['Age'].describe(include="all")

hr['Age'].quantile(.75) - hr['Age'].quantile(.25)
# Out:
# 13.0

# %% [markdown]
# ### Find out the mean, median and variance for the column - DailyRate

# %%
#hr['DailyRate'].describe(include="all")
print(hr['DailyRate'].mean())
print(hr['DailyRate'].median())
print(hr['DailyRate'].var())
# Out:
# 802.4857142857143
# 802.0
# 162819.59373723628

# %% [markdown]
# ### Plot the attrition column (Since it is a categorical variable, chose the plot accordingly)

# %%
#import seaborn as sns
#import matplotlib.pyplot as plt
#sns.set(style="ticks", color_codes=True)
#sns.catplot( y="Attrition", data=hr); 
#hr["Attrition"].value_counts()

import matplotlib.pyplot as plt
# %matplotlib inline

##histogram
hr["Attrition"].value_counts().plot(kind='bar')
hr["Attrition"].value_counts()
# Out:
# No     1233
# Yes     237
# Name: Attrition, dtype: int64

# %% [markdown]
# ### Plot Total working years using matplotlib plot function

# %%
#print(hr["TotalWorkingYears"].value_counts())
#hr["TotalWorkingYears"].value_counts().plot(kind='bar',sort_columns=True)
#hr["Attrition"].value_counts().plot(kind='bar
#hr.sort_values(by="TotalWorkingYears")["TotalWorkingYears"].value_counts().sort_values(0)
#hr.sort_values(by="TotalWorkingYears")["TotalWorkingYears"].sort_values().iloc[:,1]
#hr["TotalWorkingYears"].to_string(index=False).head()


import seaborn as sns
sns.set(style="darkgrid")
ax = sns.countplot(x="TotalWorkingYears", data=hr)

# %%
pd.cut(hr["TotalWorkingYears"], [0,10,20,30,40],labels=['0-10','10-20','20-30','30-40']).value_counts().plot(kind='bar',title='Employee count by experience')
